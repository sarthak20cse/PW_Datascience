# %% [markdown]
# # Assignment Code: DS-AG-022
#
# # Image Classification using CNN Architectures
#
# | Assignment
#
# Instructions: Carefully read each question. Use Google Docs, Microsoft Word, or a similar tool
# to create a document where you type out each question along with its answer. Save the
# document as a PDF, and then upload it to the LMS. Please do not zip or archive the files before
# uploading them. Each question carries 20 marks.
# Total Marks: 200
#
# Question 1: What is a Convolutional Neural Network (CNN), and how does it differ from
# traditional fully connected neural networks in terms of architecture and performance on
# image data?
#
# Question 2: Discuss the architecture of LeNet-5 and explain how it laid the foundation
# for modern deep learning models in computer vision. Include references to its original
# research paper.
#
# Question 3: Compare and contrast AlexNet and VGGNet in terms of design principles,
# number of parameters, and performance. Highlight key innovations and limitations of
# each.
#
# Question 4: What is transfer learning in the context of image classification? Explain
# how it helps in reducing computational costs and improving model performance with
# limited data.
#
# Question 5: Describe the role of residual connections in ResNet architecture. How do
# they address the vanishing gradient problem in deep CNNs?
#
# Question 6: Implement the LeNet-5 architectures using Tensorflow or PyTorch to
# classify the MNIST dataset. Report the accuracy and training time.
# (Include your Python code and output in the code box below.)
#
# Question 7: Use a pre-trained VGG16 model (via transfer learning) on a small custom
# dataset (e.g., flowers or animals). Replace the top layers and fine-tune the model.
# Include your code and result discussion.
# (Include your Python code and output in the code box below.)
#
# Question 8: Write a program to visualize the filters and feature maps of the first
# convolutional layer of AlexNet on an example input image.
# (Include your Python code and output in the code box below.)
#
# Question 9: Train a GoogLeNet (Inception v1) or its variant using a standard dataset
# like CIFAR-10. Plot the training and validation accuracy over epochs and analyze
# overfitting or underfitting.
# (Include your Python code and output in the code box below.)
#
# Question 10: You are working in a healthcare AI startup. Your team is tasked with
# developing a system that automatically classifies medical X-ray images into normal,
# pneumonia, and COVID-19. Due to limited labeled data, what approach would you
# suggest using among CNN architectures discussed (e.g., transfer learning with ResNet
# or Inception variants)? Justify your approach and outline a deployment strategy for
# production use.
# (Include your Python code and output in the code box below.)

# %% [markdown]
# Question 1
# What is a Convolutional Neural Network (CNN), and how does it differ from traditional fully connected neural networks in terms of architecture and performance on image data?
# Answer:
#
# A Convolutional Neural Network (CNN) is a type of deep learning model specifically designed to process structured grid data such as images. CNNs automatically learn spatial features such as edges, textures, and shapes using convolution operations.
#
# CNN Architecture Components:
# Convolution Layer
# Applies filters (kernels)
# Extracts spatial features
# Detects edges, shapes, textures
# Activation Function
# Usually ReLU
# Introduces non-linearity
# Pooling Layer
# Reduces spatial size
# Decreases computation
# Prevents overfitting
# Fully Connected Layer
# Final classification
# Outputs probabilities
# Difference Between CNN and Fully Connected Neural Networks
# | Feature               | CNN                    | Fully Connected NN          |
# | --------------------- | ---------------------- | --------------------------- |
# | Input Handling        | Uses spatial structure | Treats input as flat vector |
# | Parameters            | Fewer                  | Very large                  |
# | Feature Learning      | Automatic              | Manual                      |
# | Performance on Images | Excellent              | Poor                        |
# | Overfitting           | Less                   | More                        |
# Performance Advantages of CNN
#
# CNNs outperform traditional neural networks on image data because:
#
# Preserve spatial relationships
# Require fewer parameters
# Detect hierarchical features
# Provide higher accuracy

# %% [markdown]
# Question 2
# Discuss the architecture of LeNet-5 and explain how it laid the foundation for modern deep learning models in computer vision. Include references to its original research paper.
# Answer:
#
# LeNet-5 is one of the earliest CNN architectures developed by:
#
# Yann LeCun et al. (1998)
#
# Original Paper:
#
# LeCun, Y., Bottou, L., Bengio, Y., & Haffner, P. (1998)
# "Gradient-Based Learning Applied to Document Recognition"
# Published in: Proceedings of the IEEE
#
# LeNet-5 Architecture
#
# Input Image: 32×32 grayscale
#
# Layers:
#
# C1 — Convolution Layer
# 6 filters
# Kernel size: 5×5
# S2 — Pooling Layer
# Average pooling
# C3 — Convolution Layer
# 16 filters
# S4 — Pooling Layer
# C5 — Convolution Layer
# F6 — Fully Connected
# Output Layer
# 10 classes
# Contributions to Modern CNNs
#
# LeNet introduced:
#
# Convolution layers
# Pooling layers
# Weight sharing
# Feature extraction hierarchy
#
# These concepts are still used in:
#
# AlexNet
# VGG
# ResNet
# EfficientNet

# %% [markdown]
# Question 3
# Compare and contrast AlexNet and VGGNet in terms of design principles, number of parameters, and performance. Highlight key innovations and limitations of each.
# Answer:
# AlexNet vs VGGNet Comparison
# | Feature     | AlexNet       | VGGNet       |
# | ----------- | ------------- | ------------ |
# | Year        | 2012          | 2014         |
# | Layers      | 8             | 16 / 19      |
# | Parameters  | ~60 million   | ~138 million |
# | Kernel Size | Large (11×11) | Small (3×3)  |
# | Activation  | ReLU          | ReLU         |
# | Dataset     | ImageNet      | ImageNet     |
#
# AlexNet Innovations
# ReLU activation
# Dropout regularization
# GPU training
# Data augmentation
# Limitations:
# Large filters
# Computationally expensive
# VGGNet Innovations
# Small 3×3 filters
# Deep architecture
# Improved accuracy
# Limitations:
# Very large parameters
# Requires high memory

# %% [markdown]
# Question 4
# What is transfer learning in the context of image classification? Explain how it helps in reducing computational costs and improving model performance with limited data.
# Answer:
#
# Transfer Learning is a technique where a pre-trained model is reused for a new task.
#
# Instead of training from scratch:
#
# Use pre-trained model
# Replace final layers
# Fine-tune model
# Benefits
# 1. Reduces Training Time
#
# Pre-trained models already learned:
#
# Edges
# Textures
# Shapes
#
# Thus:
#
# Less computation required.
#
# 2. Works With Small Dataset
#
# Important when:
#
# Limited labeled data
# Expensive datasets
#
# Example:
#
# Medical images
#
# 3. Improves Accuracy
#
# Pre-trained models trained on:
#
# ImageNet (1M+ images)
#
# Result:
#
# Better generalization.

# %% [markdown]
# Question 5
# Describe the role of residual connections in ResNet architecture. How do they address the vanishing gradient problem in deep CNNs?
# Answer:
#
# Residual Connections allow gradients to flow directly through layers.
#
# Introduced in:
#
# ResNet (He et al., 2015)
#
# Residual Learning
#
# Instead of learning:
#
# H(x)
#
# Model learns:
#
# F(x) = H(x) − x
#
# Output becomes:
#
# H(x) = F(x) + x
#
# How It Solves Vanishing Gradient
#
# Traditional deep networks:
#
# Gradients become very small
# Training stops
#
# Residual connections:
#
# Provide shortcut paths
# Preserve gradient flow
# Allow very deep networks (100+ layers)

# %% [markdown]
# Question 6
# Implement the LeNet-5 architectures using Tensorflow or PyTorch to classify the MNIST dataset. Report the accuracy and training time.
#
# (Include your Python code and output in the code box below.)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import time

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape
x_train = x_train.reshape(-1,28,28,1)
x_test = x_test.reshape(-1,28,28,1)

# Build LeNet-5 Model
model = models.Sequential([

    layers.Conv2D(6,(5,5),activation='relu',input_shape=(28,28,1)),
    layers.AveragePooling2D(pool_size=(2,2)), # Added pool_size

    layers.Conv2D(16,(5,5),activation='relu'),
    layers.AveragePooling2D(pool_size=(2,2)), # Added pool_size

    layers.Flatten(),

    layers.Dense(120,activation='relu'),
    layers.Dense(84,activation='relu'),

    layers.Dense(10,activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train Model
start_time = time.time()

history = model.fit(
    x_train,
    y_train,
    epochs=5,
    validation_data=(x_test,y_test)
)

end_time = time.time()

training_time = end_time - start_time

# Evaluate
test_loss, test_accuracy = model.evaluate(x_test,y_test)

print("Test Accuracy:", test_accuracy)
print("Training Time:", training_time)
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 24, 24, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 12, 12, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ...

# %% [markdown]
# Question 7
# Use a pre-trained VGG16 model (via transfer learning) on a small custom dataset (e.g., flowers or animals). Replace the top layers and fine-tune the model. Include your code and result discussion.

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# --- Start of code copied from cell 1e67c290 to ensure dataset is present ---
# Download and extract the flower dataset
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url, fname='flower_photos', untar=True)

# The dataset will be extracted to ~/.keras/datasets/flower_photos
# Due to nesting, the actual images are in a subfolder named 'flower_photos'
# So, we adjust the dataset_path to point to this inner directory
dataset_path = os.path.join(data_dir, 'flower_photos')

print(f"Dataset downloaded and extracted to: {dataset_path}")
# --- End of copied code ---

# Determine the number of classes explicitly from the directory structure
class_names = sorted(os.listdir(dataset_path))
num_classes = len([name for name in class_names if os.path.isdir(os.path.join(dataset_path, name))])
print(f"Number of classes (explicitly determined): {num_classes}")

# Data Generator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

print(f"Train data num_classes (from generator): {train_data.num_classes}")
print(f"Validation data num_classes (from generator): {val_data.num_classes}")

# Load Pretrained VGG16
base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

# Add Custom Layers
x = base_model.output
x = layers.Flatten()(x)
x = layers.Dense(128,activation='relu')(x)
x = layers.Dropout(0.5)(x)

predictions = layers.Dense(
    num_classes, # Use the explicitly determined num_classes
    activation='softmax'
)(x)

model = models.Model(
    inputs=base_model.input,
    outputs=predictions
)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# Train
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5
)

# Evaluate
loss, acc = model.evaluate(val_data)

print("Validation Accuracy:", acc)
# Out:
# Dataset downloaded and extracted to: /root/.keras/datasets/flower_photos/flower_photos
# Number of classes (explicitly determined): 5
# Found 2939 images belonging to 5 classes.
# Found 731 images belonging to 5 classes.
# Train data num_classes (from generator): 5
# Validation data num_classes (from generator): 5
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ...

# %% [markdown]
# Question 8
# Write a program to visualize the filters and feature maps of the first convolutional layer of AlexNet on an example input image.

# %%
import torch
import torchvision.models as models
import matplotlib.pyplot as plt
import numpy as np
from torchvision import transforms
from PIL import Image

# Load AlexNet
model = models.alexnet(pretrained=True)
model.eval() # Set model to evaluation mode

# Get First Layer Filters
# The first convolutional layer is model.features[0]
filters = model.features[0].weight.data

print("Visualizing Filters of the First Convolutional Layer...")
# Visualize Filters
fig_filters = plt.figure(figsize=(10, 10))
plt.suptitle('Filters of the First Convolutional Layer (AlexNet)', fontsize=16)

# Display up to 16 filters (assuming 3 color channels, we'll pick the first channel for each filter)
for i in range(min(filters.shape[0], 16)):
    ax = fig_filters.add_subplot(4, 4, i + 1)
    # Taking one channel from the filter to display as grayscale
    img = filters[i, 0, :, :].cpu().numpy()
    plt.imshow(img, cmap='gray')
    plt.axis('off')
plt.show()

print("\nVisualizing Feature Maps for an Example Input Image...")

# --- Visualize Feature Maps for an Example Input Image ---

# 1. Load an example image (using a dummy image for demonstration)
# For a real scenario, you'd load an image like: Image.open('path/to/image.jpg')
# Let's create a random tensor for now that mimics an image
# AlexNet expects 3-channel (RGB) images of size 224x224
example_image_tensor = torch.randn(1, 3, 224, 224) # Batch size 1, 3 channels, 224x224

# If you want to use a real image, uncomment and modify this section:
# img_path = tf.keras.utils.get_file(
#     'red_panda.jpg',
#     'http://storage.googleapis.com/download.tensorflow.org/example_images/red_panda.jpg')
# img = Image.open(img_path).convert('RGB')
#
# preprocess = transforms.Compose([
#     transforms.Resize(256),
#     transforms.CenterCrop(224),
#     transforms.ToTensor(),
#     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
# ])
# example_image_tensor = preprocess(img).unsqueeze(0) # Add batch dimension

# 2. Get the output (feature maps) of the first convolutional layer
# The first convolutional layer is model.features[0]
with torch.no_grad(): # Disable gradient calculation for inference
    feature_maps = model.features[0](example_image_tensor)

# 3. Visualize Feature Maps
# Assuming we want to visualize the first 16 feature maps (if available)
num_feature_maps_to_display = min(feature_maps.shape[1], 16)

fig_feature_maps = plt.figure(figsize=(12, 12))
plt.suptitle('Feature Maps of the First Convolutional Layer (AlexNet)', fontsize=16)

for i in range(num_feature_maps_to_display):
    ax = fig_feature_maps.add_subplot(4, 4, i + 1)
    # Convert the feature map tensor to numpy and display
    # Squeeze to remove batch dimension, take channel i
    feature_map_i = feature_maps.squeeze(0)[i].cpu().numpy()
    plt.imshow(feature_map_i, cmap='viridis') # Use a colormap like 'viridis' or 'gray'
    plt.title(f'Map {i+1}')
    plt.axis('off')

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:01<00:00, 184MB/s]
# Visualizing Filters of the First Convolutional Layer...
# Visualizing Feature Maps for an Example Input Image...

# %% [markdown]
# Question 9
# Train a GoogLeNet (Inception v1) or its variant using a standard dataset like CIFAR-10. Plot the training and validation accuracy over epochs and analyze overfitting or underfitting.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, applications

# Load CIFAR-10
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize and prepare data pipeline to avoid OOM
IMG_SIZE = 150
BATCH_SIZE = 32

def preprocess(image, label):
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_ds = train_ds.shuffle(1000).map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

val_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
val_ds = val_ds.map(preprocess).batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# Load InceptionV3 pre-trained on ImageNet
base_model = applications.InceptionV3(
    weights='imagenet',
    include_top=False,
    input_shape=(IMG_SIZE, IMG_SIZE, 3)
)
base_model.trainable = False

# Build model
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
history = model.fit(train_ds, validation_data=val_ds, epochs=10)

# Plotting
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# ...
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 7s 0us/step
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 91s 48ms/step - accuracy: 0.6630 - loss: 1.0108 - val_accuracy: 0.7704 - val_loss: 0.6822
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7221 - loss: 0.8188 - val_accuracy: 0.7797 - val_loss: 0.6569
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7410 - loss: 0.7671 - val_accuracy: 0.7895 - val_loss: 0.6392
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7512 - loss: 0.7346 - val_accuracy: 0.7890 - val_loss: 0.6317
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7584 - loss: 0.7064 - val_accuracy: 0.7907 - val_loss: 0.6287
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 55s 35ms/step - accuracy: 0.7642 - loss: 0.6880 - val_accuracy: 0.7923 - val_loss: 0.6098
# Epoch 7/10
# ...

# %% [markdown]
# Question 10
# Healthcare AI Startup Scenario
#
# You are working in a healthcare AI startup. Your team is tasked with developing a system that automatically classifies medical X-ray images into normal, pneumonia, and COVID-19. Due to limited labeled data, what approach would you suggest using among CNN architectures discussed (e.g., transfer learning with ResNet or Inception variants)? Justify your approach and outline a deployment strategy for production use.
#
# Answer
# Recommended Approach:
#
# Transfer Learning with ResNet50
#
# Why:
#
# Works well with small datasets
# High accuracy
# Deep architecture
# Residual connections improve learning

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import numpy as np
import cv2

# --- Create a synthetic dataset for demonstration purposes ---
os.makedirs('/content/xray_dataset/normal', exist_ok=True)
os.makedirs('/content/xray_dataset/pneumonia', exist_ok=True)
os.makedirs('/content/xray_dataset/covid', exist_ok=True)

def create_dummy_images(path, count):
    for i in range(count):
        img = np.random.randint(0, 255, (224, 224, 3), dtype=np.uint8)
        cv2.imwrite(os.path.join(path, f'img_{i}.png'), img)

create_dummy_images('/content/xray_dataset/normal', 20)
create_dummy_images('/content/xray_dataset/pneumonia', 20)
create_dummy_images('/content/xray_dataset/covid', 20)

dataset_path = "/content/xray_dataset"

# Data Augmentation & Loading
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.15
)

train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=8,
    class_mode='categorical',
    subset='training'
)

val_data = datagen.flow_from_directory(
    dataset_path,
    target_size=(224,224),
    batch_size=8,
    class_mode='categorical',
    subset='validation'
)

# Load Pretrained ResNet50
base_model = ResNet50(
    weights='imagenet',
    include_top=False,
    input_shape=(224,224,3)
)

# Freeze base layers
base_model.trainable = False

# Build the classification head
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(train_data.num_classes, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train for a few epochs to demonstrate the process
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=3
)
# Out:
# Found 48 images belonging to 3 classes.
# Found 12 images belonging to 3 classes.
# ...
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step
# Epoch 1/3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 24s 2s/step - accuracy: 0.5000 - loss: 1.2423 - val_accuracy: 0.3333 - val_loss: 1.2464
# Epoch 2/3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.3333 - loss: 1.4047 - val_accuracy: 0.3333 - val_loss: 1.1086
# Epoch 3/3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.2917 - loss: 1.3697 - val_accuracy: 0.3333 - val_loss: 1.1898
